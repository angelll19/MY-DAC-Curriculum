# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data= pd.read_csv('Dataset/Gym_membership.csv')

# %%
data.isnull().sum()
# Out:
# Age                              0
# Gender                           0
# Weight (kg)                      0
# Height (m)                       0
# Max_BPM                          0
# Avg_BPM                          0
# Resting_BPM                      0
# Session_Duration (hours)         0
# Calories_Burned                  0
# Workout_Type                     0
# Fat_Percentage                   0
# Water_Intake (liters)            0
# Workout_Frequency (days/week)    0
# Experience_Level                 0
# BMI                              0
# dtype: int64

# %%
data.head(5)
# Out:
#    Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0   56    Male         88.3        1.71      180      157           60
# 1   46  Female         74.9        1.53      179      151           66
# 2   32  Female         68.1        1.66      167      122           54
# 3   25    Male         53.2        1.70      190      164           56
# 4   38    Male         46.1        1.79      188      158           68
#
#    Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 0                      1.69           1313.0         Yoga            12.6
# 1                      1.30            883.0         HIIT            33.9
# 2                      1.11            677.0       Cardio            33.4
# 3                      0.59            532.0     Strength            28.8
# 4                      0.64            556.0     Strength            29.2
#
#    Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# ...

# %%
calory_workout = data.groupby(['Workout_Type', 'Workout_Frequency (days/week)'])['Calories_Burned'].mean().reset_index(name= "average calories burned")
calory_workout
# Out:
#    Workout_Type  Workout_Frequency (days/week)  average calories burned
# 0        Cardio                              2               690.444444
# 1        Cardio                              3               821.771739
# 2        Cardio                              4              1012.506494
# 3        Cardio                              5              1238.565217
# 4          HIIT                              2               752.785714
# 5          HIIT                              3               831.639535
# 6          HIIT                              4              1009.761194
# 7          HIIT                              5              1300.423077
# 8      Strength                              2               789.511111
# 9      Strength                              3               802.941176
# 10     Strength                              4               986.529412
# 11     Strength                              5              1295.269231
# ...

# %%
plt.figure(figsize= (10,6))
sns.barplot(data= calory_workout, x= "Workout_Type", y= "average calories burned", hue= "Workout_Frequency (days/week)")
plt.legend (loc= "upper left", fontsize= "small")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 plt.figure(figsize= (10,6))
# ----> 2 sns.barplot(data= calory_workout, x= "Workout_Type", y= "average calories burned", hue= "Workout_Frequency (days/week)")
#       3 plt.legend (loc= "upper left", fontsize= "small")
#
# NameError: name 'sns' is not defined

# %%
min(data['Age']) #18
max(data['Age']) #59
# Out:
# 59

# %%
data['Age_Segment'] = pd.cut(data['Age'], 
                              bins=[18, 30, 40, 50, 60], 
                              labels=['18-30', '31-40', '41-50', '51-60'], 
                              right=False)

# %%
gender_age = data.groupby('Gender')['Age_Segment'].value_counts()
gender_age
# Out:
# Gender  Age_Segment
# Female  18-30          133
#         51-60          116
#         41-50          111
#         31-40          102
# Male    18-30          143
#         41-50          134
#         51-60          127
#         31-40          107
# Name: count, dtype: int64

# %%
data.head(5)
# Out:
#    Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0   56    Male         88.3        1.71      180      157           60
# 1   46  Female         74.9        1.53      179      151           66
# 2   32  Female         68.1        1.66      167      122           54
# 3   25    Male         53.2        1.70      190      164           56
# 4   38    Male         46.1        1.79      188      158           68
#
#    Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 0                      1.69           1313.0         Yoga            12.6
# 1                      1.30            883.0         HIIT            33.9
# 2                      1.11            677.0       Cardio            33.4
# 3                      0.59            532.0     Strength            28.8
# 4                      0.64            556.0     Strength            29.2
#
#    Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# ...

# %%
data['Workout_Frequency (days/week)'].value_counts()
# Out:
# Workout_Frequency (days/week)
# 3    368
# 4    306
# 2    197
# 5    102
# Name: count, dtype: int64

# %%
data.head()
# Out:
#    Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0   56    Male         88.3        1.71      180      157           60
# 1   46  Female         74.9        1.53      179      151           66
# 2   32  Female         68.1        1.66      167      122           54
# 3   25    Male         53.2        1.70      190      164           56
# 4   38    Male         46.1        1.79      188      158           68
#
#    Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 0                      1.69           1313.0         Yoga            12.6
# 1                      1.30            883.0         HIIT            33.9
# 2                      1.11            677.0       Cardio            33.4
# 3                      0.59            532.0     Strength            28.8
# 4                      0.64            556.0     Strength            29.2
#
#    Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# ...

# %%
Experience_frequency =data.groupby('Experience_Level')['Workout_Frequency (days/week)'].value_counts().reset_index(name = "Number_of_people")
Experience_frequency
# Out:
#    Experience_Level  Workout_Frequency (days/week)  Number_of_people
# 0                 1                              2               197
# 1                 1                              3               179
# 2                 2                              4               217
# 3                 2                              3               189
# 4                 3                              5               102
# 5                 3                              4                89

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize= (10,6))
sns.barplot(data=Experience_frequency, x='Workout_Frequency (days/week)', y='Number_of_people', hue='Experience_Level')
plt.title('Workout Frequency Distribution by Experience Level ')
plt.xlabel('Workout Frequency per Week')
plt.ylabel('Number of Gym Members')
plt.show()

# %%
data['user'] = 1 
   #for experience level 1, if u work out 2 and 3 days what's the differences
experience_level1 = data[data['Experience_Level']==1]
experience_level1['Workout_Type'].value_counts()
# Out:
# Workout_Type
# Cardio      109
# Strength     97
# HIIT         85
# Yoga         85
# Name: count, dtype: int64

# %%
trying =experience_level1.groupby (['Workout_Type','Workout_Frequency (days/week)'])[['Calories_Burned','Session_Duration (hours)']].mean().reset_index()
trying
# Out:
#   Workout_Type  Workout_Frequency (days/week)  Calories_Burned  \
# 0       Cardio                              2       690.444444
# 1       Cardio                              3       727.500000
# 2         HIIT                              2       752.785714
# 3         HIIT                              3       736.813953
# 4     Strength                              2       789.511111
# 5     Strength                              3       716.538462
# 6         Yoga                              2       690.510638
# 7         Yoga                              3       726.631579
#
#    Session_Duration (hours)
# 0                  0.959841
# 1                  1.023043
# 2                  1.050714
# 3                  1.043721
# 4                  1.083333
# 5                  0.995962
# 6                  0.939574
# 7                  1.015789

# %%
plt.figure(figsize= (10,6))
sns.barplot(data= trying, x= "Workout_Type", y = "Calories_Burned", hue = "Workout_Frequency (days/week)" )
plt.title("Calories Burned per Workout Type & Workout Frequency when Experience Level = 1 ")
plt.legend(loc= "upper left", fontsize= "small")
#at experience level = 1, by logic, if u come to gym more frequent, u will burn more calory 
# but HIIT and Strength doesn't like that
# when the frequency of coming to gym is 3, it is lower calories burned than when frequency is 2

# %%
experience_level2 = data[data['Experience_Level']==2]


trying_2 =experience_level2.groupby (['Workout_Type','Workout_Frequency (days/week)'])[['Calories_Burned','Session_Duration (hours)']].mean().reset_index()
trying_2
# Out:
#   Workout_Type  Workout_Frequency (days/week)  Calories_Burned  \
# 0       Cardio                              3       916.043478
# 1       Cardio                              4       940.892857
# 2         HIIT                              3       926.465116
# 3         HIIT                              4       870.454545
# 4     Strength                              3       892.800000
# 5     Strength                              4       902.151515
# 6         Yoga                              3       913.060000
# 7         Yoga                              4       850.549020
#
#    Session_Duration (hours)
# 0                  1.239130
# 1                  1.255179
# 2                  1.280465
# 3                  1.250682
# 4                  1.238200
# 5                  1.248485
# 6                  1.252600
# 7                  1.221961

# %%
experience_level3 = data[data['Experience_Level']==3]


trying_3 =experience_level3.groupby (['Workout_Type','Workout_Frequency (days/week)'])[['Calories_Burned','Session_Duration (hours)']].mean().reset_index()
trying_3
# Out:
#   Workout_Type  Workout_Frequency (days/week)  Calories_Burned  \
# 0       Cardio                              4      1203.476190
# 1       Cardio                              5      1238.565217
# 2         HIIT                              4      1276.260870
# 3         HIIT                              5      1300.423077
# 4     Strength                              4      1279.631579
# 5     Strength                              5      1295.269231
# 6         Yoga                              4      1247.230769
# 7         Yoga                              5      1271.740741
#
#    Session_Duration (hours)
# 0                  1.710000
# 1                  1.756087
# 2                  1.713913
# 3                  1.766154
# 4                  1.771053
# 5                  1.793077
# 6                  1.778077
# 7                  1.773333

# %%
plt.figure(figsize= (10,6))
sns.lineplot(data= trying, x= "Workout_Type", y = "Session_Duration (hours)", hue = "Workout_Frequency (days/week)")
plt.title("Average Duration per Workout Type & Workout Frequency when Experience Level = 1 ")
#come more frequent doesn't mean they workout more time
# this is why frequency coming = 3 is burn lower calory when frequency come = 2
# Out:
# Text(0.5, 1.0, 'Average Duration per Workout Type & Workout Frequency when Experience Level = 1 ')

# %%
#calories burned per day
experience_level1['Calories_per_day']= experience_level1['Calories_Burned'] / experience_level1['Workout_Frequency (days/week)']
experience_level1['Session_hours_day'] = experience_level1['Session_Duration (hours)'] / experience_level1['Workout_Frequency (days/week)']
try2 =experience_level1.groupby(['Workout_Type', 'Workout_Frequency (days/week)'])[['Calories_per_day', 'Session_hours_day']].mean()
try2
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_19304\625004360.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   experience_level1['Calories_per_day']= experience_level1['Calories_Burned'] / experience_level1['Workout_Frequency (days/week)']
# C:\Users\Dell\AppData\Local\Temp\ipykernel_19304\625004360.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   experience_level1['Session_hours_day'] = experience_level1['Session_Duration (hours)'] / experience_level1['Workout_Frequency (days/week)']
# ...

# %%
# even they come more, actually the spend less hour 
plt.figure(figsize= (10,6))
sns.barplot(data= try2, x= "Workout_Type", y= "Calories_per_day", hue= "Workout_Frequency (days/week)")
plt.legend(fontsize= "small")
plt.title('Calories Burned per Day by Workout Frequency')
# Out:
# Text(0.5, 1.0, 'Calories Burned per Day by Workout Frequency')

# %%
# even they come more, actually the spend less hour 
plt.figure(figsize= (10,6))
sns.lineplot(data= try2, x= "Workout_Type", y= "Session_hours_day", hue= "Workout_Frequency (days/week)")
plt.title('Session Duration per Day by Workout Frequency')
plt.legend (loc="upper right", fontsize= "small")

# %%
c =experience_level1.groupby (['Workout_Type','Workout_Frequency (days/week)'])[['Calories_Burned','Session_Duration (hours)','user']].sum().reset_index()
c
# Out:
#   Workout_Type  Workout_Frequency (days/week)  Calories_Burned  \
# 0       Cardio                              2          43498.0
# 1       Cardio                              3          33465.0
# 2         HIIT                              2          31617.0
# 3         HIIT                              3          31683.0
# 4     Strength                              2          35528.0
# 5     Strength                              3          37260.0
# 6         Yoga                              2          32454.0
# 7         Yoga                              3          27612.0
#
#    Session_Duration (hours)  user
# 0                     60.47    63
# 1                     47.06    46
# 2                     44.13    42
# 3                     44.88    43
# 4                     48.75    45
# 5                     51.79    52
# 6                     44.16    47
# 7                     38.60    38

# %%
data.head()
# Out:
#    Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0   56    Male         88.3        1.71      180      157           60
# 1   46  Female         74.9        1.53      179      151           66
# 2   32  Female         68.1        1.66      167      122           54
# 3   25    Male         53.2        1.70      190      164           56
# 4   38    Male         46.1        1.79      188      158           68
#
#    Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 0                      1.69           1313.0         Yoga            12.6
# 1                      1.30            883.0         HIIT            33.9
# 2                      1.11            677.0       Cardio            33.4
# 3                      0.59            532.0     Strength            28.8
# 4                      0.64            556.0     Strength            29.2
#
#    Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# ...

# %%
Workout_Gender_Calory = data.groupby(['Gender','Workout_Type'])['Calories_Burned'].mean().reset_index(name= "Average Calories Burned")
Workout_Gender_Calory
# Out:
#    Gender Workout_Type  Average Calories Burned
# 0  Female       Cardio               834.793651
# 1  Female         HIIT               869.953271
# 2  Female     Strength               863.097561
# 3  Female         Yoga               886.122642
# 4    Male       Cardio               933.077519
# 5    Male         HIIT               978.228070
# 6    Male     Strength               954.066667
# 7    Male         Yoga               916.789474

# %%
plt.figure(figsize= (10,6))
sns.barplot (data= Workout_Gender_Calory, x="Workout_Type", y="Average Calories Burned", hue= "Gender", palette= {"Female" :"pink", "Male": "#ADD8E6"} )
plt.title('Average Calories Burned by Workout Type & Gender')
plt.xlabel ("Workout Type")
plt.legend(loc="upper right", fontsize= "small")
plt.show()

# %%
ss= data.groupby(['Gender', 'Workout_Type'])['Session_Duration (hours)'].mean().reset_index(name="Average_Session_Duration")
#female spent more time on Strenght and Yoga than male, but why male burned more calory

# %%
plt.figure(figsize= (10,6))
sns.barplot(data= ss, x= "Workout_Type", y="Average_Session_Duration", hue='Gender', palette= {'Female':'Pink', "Male":"lightblue"})
plt.legend(loc="upper left", fontsize = "small")
plt.title("Average Session Duration by Workout Type & Gender")
plt.xlabel("Workout Type")
plt.ylabel("Average Session Duration")
# Out:
# Text(0, 0.5, 'Average Session Duration')

# %%
dat =data.groupby(['Gender','Workout_Type'])['Experience_Level'].value_counts().reset_index(name ="count")
dat
#male is more than female



# Create a pivot table to get counts of Experience_Level for each Gender and Workout_Type
pivot = dat.pivot_table(index=['Workout_Type', 'Experience_Level'], columns='Gender', values='count', aggfunc='sum', fill_value=0)

# Plot the stacked bar plot
pivot.plot(kind='bar', stacked=False, figsize=(12, 6), color=['#ADD8E6', '#FFB3C6'])

# Add titles and labels
plt.title('Stacked Count of Experience Level by Gender and Workout Type')
plt.xlabel('Workout Type and Experience Level')
plt.ylabel('Count of People')

# Display the plot
plt.show()

# %%
data.groupby(['Gender', 'Workout_Type','Experience_Level'])['Avg_BPM'].mean()
# Out:
# Gender  Workout_Type  Experience_Level
# Female  Cardio        1                   144.220339
#                       2                   145.222222
#                       3                   141.681818
#         HIIT          1                   142.682927
#                       2                   143.851064
#                       3                   148.210526
#         Strength      1                   142.085106
#                       2                   148.129630
#                       3                   133.545455
#         Yoga          1                   140.875000
#                       2                   144.276596
#                       3                   143.000000
# Male    Cardio        1                   141.680000
#                       2                   146.105263
#                       3                   141.772727
#         HIIT          1                   142.113636
#                       2                   141.700000
# ...

# %%
bins = [0,18.49,24.99,29.99,50]
labels = ['Underweight', 'Normal', 'Overweight', 'Obese']
data['BMI Category'] =pd.cut(data['BMI'], bins= bins,  labels= labels, right=True)

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data= data, x="BMI Category", y="Calories_Burned", hue="Gender")
plt.title("Calories Burned per BMI Category & Gender")
# Out:
# Text(0.5, 1.0, 'Calories Burned per BMI Category & Gender')

# %%
sns.scatterplot(data= data, x="Fat_Percentage", y="Water_Intake (liters)", hue='Gender')
sns.violinplot(data=data, x='Gender', y='Water_Intake (liters)', inner="quart", palette={"Female": "pink", "Male": "lightblue"})
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_19304\3630045120.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=data, x='Gender', y='Water_Intake (liters)', inner="quart", palette={"Female": "pink", "Male": "lightblue"})
# <Axes: xlabel='Fat_Percentage', ylabel='Water_Intake (liters)'>

# %%
plt.figure(figsize= (10,6))
sns.lineplot(data= data, x= "Water_Intake (liters)", y= "Fat_Percentage", hue="Gender")
plt.title("Water Intake & Fat Percentage per Gender")
plt.ylabel("Fat Percentage")
plt.xlabel("Water Intake")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# For example, let's say the data is already loaded in a variable called 'data'

# Create bins for 'Water_Intake' (you can adjust the bins based on your data)
bins = [0, 1, 2, 3, 4, 5]  # Example bins for water intake in liters
labels = ['0-1', '1-2', '2-3', '3-4', '4-5']
data['Water_Intake_Binned'] = pd.cut(data['Water_Intake (liters)'], bins=bins, labels=labels, right=False)

# Calculate average fat percentage per bin for each gender
avg_data = data.groupby(['Water_Intake_Binned', 'Gender'])['Fat_Percentage'].mean().reset_index()

# Plot the line plot for male and female
plt.figure(figsize=(10, 6))
sns.lineplot(data=avg_data, x='Water_Intake_Binned', y='Fat_Percentage', hue='Gender', marker='o', palette={'Female': 'pink', 'Male': 'lightblue'})

# Add titles and labels
plt.title('Average Fat Percentage vs Water Intake by Gender', fontsize=16)
plt.xlabel('Water Intake (liters)', fontsize=14)
plt.ylabel('Average Fat Percentage (%)', fontsize=14)

# Show plot
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_19304\1535286394.py:13: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_data = data.groupby(['Water_Intake_Binned', 'Gender'])['Fat_Percentage'].mean().reset_index()

# %%
data.head()
# Out:
#    Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0   56    Male         88.3        1.71      180      157           60
# 1   46  Female         74.9        1.53      179      151           66
# 2   32  Female         68.1        1.66      167      122           54
# 3   25    Male         53.2        1.70      190      164           56
# 4   38    Male         46.1        1.79      188      158           68
#
#    Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 0                      1.69           1313.0         Yoga            12.6
# 1                      1.30            883.0         HIIT            33.9
# 2                      1.11            677.0       Cardio            33.4
# 3                      0.59            532.0     Strength            28.8
# 4                      0.64            556.0     Strength            29.2
#
#    Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# ...

# %%
# Import our libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_iris
from sklearn import tree

# %%
# Separate the Titanic data into features and target class.
data = pd.get_dummies(data, drop_first=True)  # drops the first level of each categorical column

y = data['BMI', 'Fat_Percentage']
x = data.drop(['BMI', 'Fat_Percentage'], axis=1) #axis=1 specifies that you're dropping a column (not a row, which would be axis=0).

# Split the data into training, validation and test data.
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3)

x_test, x_eval, y_test, y_eval = train_test_split(x_test, y_test, test_size = 0.5)

# Create decision tree models of various depths, 
# and measure the accuracy of validation data for each model.
train_acc = []
eval_acc = []
max_depth = 8
for d in range(1, max_depth+1):
    model = DecisionTreeClassifier(max_depth=d)
    model.fit(x_train, y_train)
    
    # Measure the accuracy of this model using the training data.
    y_pred = model.predict(x_train)
    train_acc.append((y_pred == y_train).mean())

    # Measure the accuracy of this model using the validation data.
    y_pred = model.predict(x_eval)
    eval_acc.append((y_pred == y_eval).mean())
    print('Depth = {}, train_acc = {:.4f}, eval_acc = {:.4f}'\
          .format(d, train_acc[-1], eval_acc[-1]))

# Find the optimal depth with the highest accuracy of validation data.
opt_depth = np.argmax(eval_acc) + 1

# Visualize accuracy changes as depth changes.
plt.plot(train_acc, marker='o', label='train')
plt.plot(eval_acc, marker='o', label='evaluation')
plt.legend()
plt.title('Accuracy')
plt.xlabel('tree depth')
plt.ylabel('accuracy')
plt.xticks(np.arange(max_depth), np.arange(1, max_depth+1))
plt.axvline(x=opt_depth-1, ls='--')
plt.ylim(0.5, 1.0)
plt.show()

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error
import seaborn as sns

# Assuming the data is loaded and contains both BMI and Fat_Percentage columns
# One-hot encode categorical features and drop the first level to avoid multicollinearity
data = pd.get_dummies(data, drop_first=True)

# Select 'BMI' and 'Fat_Percentage' as target variables, rest as features
y = data[['BMI', 'Fat_Percentage']]  # Now selecting both columns correctly
x = data.drop(['BMI', 'Fat_Percentage'], axis=1)  # Dropping target columns from the feature set

# Split the data into training, validation, and test sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)
x_test, x_eval, y_test, y_eval = train_test_split(x_test, y_test, test_size=0.5, random_state=42)

# Create decision tree models of various depths and measure the accuracy of validation data for each model
train_mse = []  # Mean Squared Error for training
eval_mse = []   # Mean Squared Error for evaluation
max_depth = 8  # Maximum tree depth to test

# Train the DecisionTreeRegressor with different depths
for d in range(1, max_depth + 1):
    model = DecisionTreeRegressor(max_depth=d, random_state=42)
    model.fit(x_train, y_train)
    
    # Measure the MSE of this model using the training data
    y_pred_train = model.predict(x_train)
    train_mse.append(mean_squared_error(y_train, y_pred_train))  # Using MSE as regression metric
    
    # Measure the MSE of this model using the evaluation data
    y_pred_eval = model.predict(x_eval)
    eval_mse.append(mean_squared_error(y_eval, y_pred_eval))  # Using MSE as regression metric
    print('Depth = {}, train_mse = {:.4f}, eval_mse = {:.4f}'.format(d, train_mse[-1], eval_mse[-1]))

# Find the optimal depth with the lowest MSE on evaluation data
opt_depth = np.argmin(eval_mse) + 1  # Get the optimal depth with min evaluation MSE

# Visualize MSE changes as depth changes
plt.plot(range(1, max_depth + 1), train_mse, marker='o', label='Train MSE')
plt.plot(range(1, max_depth + 1), eval_mse, marker='o', label='Evaluation MSE')
plt.legend()
plt.title('MSE vs. Tree Depth')
plt.xlabel('Tree Depth')
plt.ylabel('Mean Squared Error')
plt.xticks(np.arange(1, max_depth + 1))
plt.axvline(x=opt_depth, ls='--', color='r', label=f'Optimal Depth = {opt_depth}')
plt.ylim(0, max(eval_mse) + 1)
plt.legend()
plt.show()

# Feature importance analysis (important for feature engineering)
# Get the feature importance from the model with the optimal depth
optimal_model = DecisionTreeRegressor(max_depth=opt_depth, random_state=42)
optimal_model.fit(x_train, y_train)

# Get the feature importances (average across both target columns, if needed)
importances = optimal_model.feature_importances_

# Create a DataFrame to display the features and their importance
feature_importance_df = pd.DataFrame({
    'Feature': x_train.columns,
    'Importance': importances
})

# Sort the features by their importance
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Print the most important features
print("Feature Importance (Top Features):")
print(feature_importance_df)

# Plot the feature importances
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importance_df)
plt.title('Feature Importance')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.show()
# Out:
# Depth = 1, train_mse = 27.7936, eval_mse = 33.9187
# Depth = 2, train_mse = 16.0957, eval_mse = 17.9657
# Depth = 3, train_mse = 10.6802, eval_mse = 11.3954
# Depth = 4, train_mse = 7.4770, eval_mse = 8.5154
# Depth = 5, train_mse = 5.4391, eval_mse = 6.5899
# Depth = 6, train_mse = 4.1126, eval_mse = 6.3127
# Depth = 7, train_mse = 3.0253, eval_mse = 7.5125
# Depth = 8, train_mse = 2.0071, eval_mse = 8.6127
# Feature Importance (Top Features):
#                           Feature  Importance
# 1                     Weight (kg)    0.436580
# 10               Experience_Level    0.352710
# 2                      Height (m)    0.113310
# 11                    Gender_Male    0.088617
# 0                             Age    0.002002
# 6        Session_Duration (hours)    0.001439
# 8           Water_Intake (liters)    0.001200
# 7                 Calories_Burned    0.001174
# 9   Workout_Frequency (days/week)    0.001056
# 4                         Avg_BPM    0.000827
# ...

# %%
# I set max_step=3 as a constant value for tree visualization.
model = DecisionTreeClassifier(max_depth=3)
model.fit(x_train, y_train)

# Use test data to evaluate final performance.
y_pred = model.predict(x_test)
test_acc = (y_pred == y_test).mean()
print('Optimal depth = {}, test_acc = {:.4f}'.format(opt_depth, test_acc))
        
# Visualize the tree
# plt.figure(figsize=(20,10))
feat_names = x.columns.tolist()
plt.figure(figsize=(14,6))
tree.plot_tree(model, feature_names = feat_names, fontsize=10)
plt.show()

# Analyze the importance of features.
feature_importance = model.feature_importances_
n_feature = x_train.shape[1]
idx = np.arange(n_feature)

plt.barh(idx, feature_importance, align='center', color='green')
plt.yticks(idx, feat_names, size=12)
plt.xlabel('importance', size=15)
plt.ylabel('feature', size=15)
plt.show()

print('feature importance = {}'.format(feature_importance.round(3)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 3
#       1 # I set max_step=3 as a constant value for tree visualization.
#       2 model = DecisionTreeClassifier(max_depth=3)
# ----> 3 model.fit(x_train, y_train)
#       5 # Use test data to evaluate final performance.
#       6 y_pred = model.predict(x_test)
#
# File c:\Users\Dell\Desktop\MY-DAC-Curriculum\.venv\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# ...

# %%
corr_matrix = data.corr(numeric_only=True)
fig,ax = plt.subplots(figsize=(12,12))
sns.heatmap(corr_matrix, annot=True)
plt.show()

# %%
data.head()
# Out:
#    Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0   56    Male         88.3        1.71      180      157           60
# 1   46  Female         74.9        1.53      179      151           66
# 2   32  Female         68.1        1.66      167      122           54
# 3   25    Male         53.2        1.70      190      164           56
# 4   38    Male         46.1        1.79      188      158           68
#
#    Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 0                      1.69           1313.0         Yoga            12.6
# 1                      1.30            883.0         HIIT            33.9
# 2                      1.11            677.0       Cardio            33.4
# 3                      0.59            532.0     Strength            28.8
# 4                      0.64            556.0     Strength            29.2
#
#    Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# ...

# %%
min(data['Fat_Percentage'])
# Out:
# 10.0

# %%
data.groupby('Workout_Type')['Calories_Burned'].mean()
# Out:
# Workout_Type
# Cardio      884.513725
# HIIT        925.805430
# Strength    910.697674
# Yoga        903.188285
# Name: Calories_Burned, dtype: float64

# %%
data.groupby(['Workout_Type','Experience_Level','Workout_Frequency (days/week)'])[['Calories_Burned','Session_Duration (hours)']].mean()
# Out:
#                                                              Calories_Burned  \
# Workout_Type Experience_Level Workout_Frequency (days/week)
# Cardio       1                2                                   690.444444
#                               3                                   727.500000
#              2                3                                   916.043478
#                               4                                   940.892857
#              3                4                                  1203.476190
#                               5                                  1238.565217
# HIIT         1                2                                   752.785714
#                               3                                   736.813953
#              2                3                                   926.465116
#                               4                                   870.454545
# ...

# %%
data['Gender'].value_counts()
# Out:
# Gender
# Male      511
# Female    462
# Name: count, dtype: int64
